# %% [markdown]
# # Matplotlib Exercises
#
# Welcome to the exercises for reviewing matplotlib! Take your time with these, Matplotlib can be tricky to understand at first. These are relatively simple plots, but they can be hard if this is your first time with matplotlib, feel free to ask about anything as you go along.
#
# Also don't worry if you find the matplotlib syntax frustrating, we actually won't be using it that often, we will switch to using seaborn and pandas built-in visualization capabilities. But, those are built-off of matplotlib, which is why it is still important to get exposure to it!
#
# ** * NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP. * **
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig = plt.figure()
ax = fig.add_axes([0.0,0.0,1.0,1.0])


ax.plot(x , y)

x_ticks = np.arange(0 , 110 , 20)
y_ticks = np.arange(0, 210 , 50)
ax.set_xticks(x_ticks)
ax.set_yticks(y_ticks)

ax.set_title('title')
ax.set_xlabel('x')
ax.set_ylabel('y')

ax.tick_params(direction="in")

ax.set_xlim(0 , 100)
ax.set_ylim(0 , 200)

ax.tick_params(bottom=True, top=True, left=True, right=True) 

plt.show()

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig = plt.figure()

x_ticks = np.arange(0 , 1.1 , 0.20)
y_ticks = np.arange(0, 1.1 , 0.20)


ax1 = fig.add_axes([0,0,1,1])
ax1.tick_params(direction="in")
ax1.set_xticks(x_ticks)
ax1.set_yticks(y_ticks)
ax1.tick_params(bottom=True, top=True, left=True, right=True) 


ax2 = fig.add_axes([0.2,0.5,.2,.2])
ax2.tick_params(direction="in")
ax2.set_xticks(x_ticks)
ax2.set_yticks(y_ticks)
ax2.tick_params(bottom=True, top=True, left=True, right=True)

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
x_ticks = np.arange(0 , 110 , 20)
y_ticks = np.arange(0, 210 , 50)

ax1.plot(x , y)
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.set_xlim(0 , 100)
ax1.set_ylim(0 , 200)
ax1.set_xticks(x_ticks)
ax1.set_yticks(y_ticks)
ax1.tick_params(bottom=True, top=True, left=True, right=True) 

ax2.plot(x , y)
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_xticks(x_ticks)
ax2.set_yticks(y_ticks)
ax2.set_xlim(0 , 100)
ax2.set_ylim(0 , 200)
ax2.tick_params(bottom=True, top=True, left=True, right=True) 

fig

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
x_ticks = np.arange(0 , 1.1 , 0.20)
y_ticks = np.arange(0, 1.1 , 0.20)

fig = plt.figure()

ax1 = fig.add_axes([0,0,1,1])
ax1.tick_params(direction="in")
ax1.set_xticks(x_ticks)
ax1.set_yticks(y_ticks)
ax1.tick_params(bottom=True, top=True, left=True, right=True) 


ax2 = fig.add_axes([0.2,0.5,.4,.4])
ax2.tick_params(direction="in")
ax2.set_xticks(x_ticks)
ax2.set_yticks(y_ticks)
ax2.tick_params(bottom=True, top=True, left=True, right=True)

# %% [markdown]
# ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
ax1.plot(x , z)
ax1.set_xlabel('x')
ax1.set_ylabel('z')
ax1.set_xlim(0 , 100)
ax1.set_ylim(0 , 10000)
x2_ticks = np.arange(0 , 110 , 20)
y2_ticks = np.arange(0, 10010 , 2000)
ax1.set_xticks(x2_ticks)
ax1.set_yticks(y2_ticks)
ax1.tick_params(bottom=True, top=True, left=True, right=True) 

ax2.plot(x , y)
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_title('zoom')
x2_ticks = np.arange(20 , 22.1 , 0.5)
y2_ticks = np.arange(30, 51 , 5)
ax2.set_xticks(x2_ticks)
ax2.set_yticks(y2_ticks)
ax2.set_xlim(20 , 22)
ax2.set_ylim(30 , 50)
ax2.tick_params(bottom=True, top=True, left=True, right=True) 

fig

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig = plt.figure()

subplot1=fig.add_subplot(1,2,1)
subplot1.tick_params(direction="in")


subplot2=fig.add_subplot(1,2,2)
subplot2.tick_params(direction="in")

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
subplot1.plot(x, y ,'r--')
subplot1.set_xlim(0 , 100)
subplot1.set_ylim(0 , 200)

subplot2.plot(x, z , linewidth = 10)
subplot2.set_xlim(0 , 100)
subplot2.set_ylim(0 , 10000)
fig

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
fig = plt.figure(figsize=(12,3))

subplot1=fig.add_subplot(1,2,1 )
subplot1.tick_params(direction="in")
subplot1.plot(x, y ,'r--')
subplot1.set_xlim(0 , 100)
subplot1.set_ylim(0 , 200)


subplot2=fig.add_subplot(1,2,2)
subplot2.tick_params(direction="in")
subplot2.plot(x, z , linewidth = 10)
subplot2.set_xlim(0 , 100)
subplot2.set_ylim(0 , 10000)

fig.show()
# Out:
# C:\Users\abdalrhman\AppData\Local\Temp\ipykernel_19564\2347586983.py:16: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# # Great Job!

# %% [markdown]
# ## #shAI Club
